# %% [markdown]
# # Systems Check - Liam Merritt

# %% [markdown]
# ### EMAT 22110 - Data in Emerging Media and Technology

# %% [markdown]
# ![avatar.png](attachment:avatar.png)

# %% [markdown]
# 1. My name is Liam Merritt
# 2. I hope to learn many things from this class.
# 3. The most important thing is that I learn how to analyze data.
# 4. I'm a senior in the Emerging Media and Technology program
# 5. I just realized my love for coding and learning new things is important to maintain growth as a human being.

# %% [markdown]
# ## Here are some code cells to prove my notebook is running correctly.

# %% [markdown]
# # Variable Assignment:

# %%
var1 = 12
var2 = 13
var1 + var2
# Out:
# 25

# %% [markdown]
# # Basic Loop:

# %%
cakes = ['Bunt','Chocolate','Carrot']         ###### https://www.w3schools.com/python/python_for_loops.asp  ######
for item in cakes:                            ###### I loosely based my loop on the information found here^ ######
    if item == 'Chocolate':                   ####################################################################
        continue
    if item == 'Carrot':
        break                         ############################################################################
    print(item + ' cake')             #### This is a loop that prints Bunt cake out of an array of variables. ####
# Out:
# Bunt cake

# %% [markdown]
# # Print Statement:

# %%
voicemail = 'Hello this is Liam Merritt, I was unable to get to the phone, please leave a message.'
print(voicemail)
# Out:
# Hello this is Liam Merritt, I was unable to get to the phone, please leave a message.

# %% [markdown]
# # Return Statement:

# %%
def funct1():                              ##### This is a function that returns a value of added integers. #####
    return 1 + 2 + 3                       ######################################################################
print(funct1())
# Out:
# 6

# %% [markdown]
# ## *End*
